# %% [markdown]
# ## BackPropagration Process:
#
# ## Steps for BackPropogration
#    ## Initialize (w1 b) such that [w1 =2, b=0]
#    ## We select a a (row (or a data point ) ) for dataset equate or passing input column from input nodes
#    ## Predict the output (Forward Proprogation)
#    ## Dot-Product : b/w weights and input
#    ## Just because prediction and actual value is not same , that why we choose loss function and that depends on type of problem
#    ## Now for this error we need to change (weight and bias) value to reduces the error , now we can change such that (weight and bias)
#    ## Hierarchy of which value depends upon which other value , and how exactly the Chain Rule Applied.
