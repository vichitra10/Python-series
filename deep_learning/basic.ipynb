# %% [markdown]
# ## Deep Learning
# ## What is Deep Learning: It is just a subfield of Artificial intelligence and Machine Learning that is inspire by the structure of the Human Brain.
# ## Deep Learning attempt to drow similiar conclusion as human would do by continusly by analysing data with a given logical structure called as Neural Network.
#
# ## GAN : Unsupervised Deep Learning Technique
#
# ## Purpose of Artifical Intelligence
# ## We want to provide Machines with the Intelligence That human beings are having
#
# ## Artificial Neural Network (ANN): It is a computing model inspired by the human brain that consists of interconnected units called neurons. The basic unit of an ANN is called a perceptron.
# ## ANN is a machine learning model inspired by the human brain, where interconnected neurons process information and learn patterns from data.
#
# ## Type of Neural Network
#     ## Supervised Technique
#
#         ## ANN (Artificial Neural Network): To perform basic computation  (ML Level problem)
#
#         ## CNN (Convolution Neural Network): Used for Image Related Data (Image Recoginition) && Self driving car using CNN
#         ## CNN is not responsible for new generate image like ghibli images
#
#         ## Transformers: GPT (Generate Pretrained Transformers)
#
#
#         ## RNN (Recurrent Neural Network) : Work for Sequential Data
#
#     ## Unsupervised Technique
#
#     ## Autoencoder & GAN  (GAN stands for Generative Adverserial Network )
#
# ## Why Deep Learning Getting so famous
#
#
#    ## 1) Applicability ---> ANN, CNN, RNN
#
#          ## There are lots of application of Deep Learning like Computer Vision , Speech Reconigition Model , Machine Translation, Compressing Images and for Generating  New Content like GENAI .
#
#    ## 2)  Performance  ----> State of the Art result and as sometime it can surpas the knowledge of human experts as well
#
# ## Working of Deep Learning
# ## AI -----> Machine Learning -----> Deep Learning
# ## Deep Learnining can also be solve ML Problem Itselg
# ## Deep Learning algorithm uses multiple layers to extract higher level features from the raw data or input data we can say.
#
# ## DL vs ML
#
#    ## 1)  Data Dependency: Whole Internet data ---> Hude amount of data (In order to get these model trained we require huge amount of data)
#    ## DL models performs better on providing huge number of data
#    ## Hardware Dependency
#
#
# ## Perceptron: Perception is an algo just like other algorithm which is used for Supervised Machine Learning. It is the Building block of the deep learning and we can call it as mathematical column and mathematical function as well
